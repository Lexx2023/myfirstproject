# %% [markdown]
# <a href="https://colab.research.google.com/github/Lexx2023/myfirstproject/blob/main/Practice_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import numpy as np
import io
from google.colab import files
Uploaded = files.upload()
Uploaded
df = pd.read_csv('New_Otchet1.csv')
df1 = pd.DataFrame(df)
str1 = df1.to_string()
print(df1.head (n=3))
print()
print(df1)
# print(str1)
print()
print (df1.info())
print()

a = df1['Кол-во мест'].mean() # Определение среднего значения Кол-во мест
b = df1['Вес г'].mean() # Определение среднего значения Вес г
c = df1['Стоимость услуги руб.'].mean() # Определение среднего значения Стоимость услуги руб.

am = df1['Кол-во мест'].median () # Определение медианы Кол-во мест
bm = df1['Вес г'].median() # Определение медианы Сумма НДС руб.
cm = df1['Стоимость услуги руб.'].median () # Определение медианы Стоимость услуги руб.

aMax = df1['Кол-во мест'].max() # Определение максимального значения Кол-во мест
bMax = df1['Вес г'].max() # Определение максимального значения Вес г
cMax = df1['Стоимость услуги руб.'].max() # Определение максимального значения Стоимость услуги руб.

aMin = df1['Кол-во мест'].min() # Определение минимального значения Кол-во мест
bMin = df1['Вес г'].min() # Определение минимального значения Вес г
cMin = df1['Стоимость услуги руб.'].min() # Определение минимального значения Стоимость услуги руб.


print(a,' ',b,' ',c,' ',' ',aMax,' ',bMax,' ',cMax,' ',aMin,' ',bMin,' ',cMin,)
# Out:
#      <input type="file" id="files-6009baa6-7b6b-47f0-b0a8-038694a0e0bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6009baa6-7b6b-47f0-b0a8-038694a0e0bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
